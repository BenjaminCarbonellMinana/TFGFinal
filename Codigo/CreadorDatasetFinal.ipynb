# %% [markdown]
# # CREAR LOS DATASETS FINALES

# %% [markdown]
# **Estacion 1/ ALICANTE**

# %%
import pandas as pd

Estacion_1_Valencia = pd.read_csv("/Users/benjamincarbonell/Documents/GitHub/TFGFinal/Datos TFG/df_media_semicompletos/df_Valencia_Media.csv")

Estacion_1_Valencia = Estacion_1_Valencia.rename(columns={
    
    "NO_mean": "NO",
    "NO2_mean": "NO2",
    "NOx_mean": "NOx",
    "O3_mean": "O3",
    "Veloc._mean": "Veloc.",
    "Direc._mean": "Direc.",
    "Temp._mean": "Temp.",
    "R.Sol._mean": "R.Sol.",
    "Pres._mean": "Pres."
})


Estacion_1_Valencia["Estacion"] = "Estacion 1"

Estacion_1_Valencia["Transecto"] = "Transecto 4"

Estacion_1_Valencia["Dist."] = 0

Estacion_1_Valencia["Angulo"] = 96.2

print(Estacion_1_Valencia.head())

Estacion_1_Valencia.to_csv("/Users/benjamincarbonell/Documents/GitHub/TFGFinal/Datos TFG/DATOSFINALES/HORARIOS/T4_E1_Valencia.csv", index=False)
# Out:
#               datetime        NO       NO2        NOx         O3    Veloc.  \
# 0  2010-01-01 00:00:00  6.000000  8.285714  16.714286  79.000000  3.533333
# 1  2010-01-01 01:00:00  5.857143  9.428571  18.142857  83.428571  4.633333
# 2  2010-01-01 02:00:00  5.285714  7.142857  14.714286  88.428571  4.833333
# 3  2010-01-01 03:00:00  4.571429  7.428571  13.714286  83.428571  3.866667
# 4  2010-01-01 04:00:00  5.285714  6.857143  14.571429  81.857143  4.100000
#
#        Direc.  Temp.  R.Sol.   Pres.    Estacion    Transecto  Dist.  Angulo
# 0  261.333333  11.25     0.0  1000.0  Estacion 1  Transecto 4      0    96.2
# 1  275.000000  11.00     0.0  1001.0  Estacion 1  Transecto 4      0    96.2
# 2  270.666667  10.80     0.0  1002.0  Estacion 1  Transecto 4      0    96.2
# 3  273.000000  10.60     0.0  1002.0  Estacion 1  Transecto 4      0    96.2
# 4  274.000000  10.50     0.0  1002.0  Estacion 1  Transecto 4      0    96.2

# %%
Estacion_1_Valencia = Estacion_1_Valencia.drop(columns=["year_source"])
