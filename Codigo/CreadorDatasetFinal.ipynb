# %% [markdown]
# # CREAR LOS DATASETS FINALES

# %% [markdown]
# **Estacion 1/ ALICANTE**

# %%
import pandas as pd

Estacion_1_Alicante = pd.read_csv("/Users/benjamincarbonell/Documents/GitHub/TFGFinal/Datos TFG/df_media_semicompletos/df_Alacant_Media.csv")

Estacion_1_Alicante = Estacion_1_Alicante.rename(columns={
    
    "NO_mean": "NO",
    "NO2_mean": "NO2",
    "NOx_mean": "NOx",
    "O3_mean": "O3",
    "Veloc._mean": "Veloc.",
    "Direc._mean": "Direc.",
    "Temp._mean": "Temp.",
    "R.Sol._mean": "R.Sol.",
    "Pres._mean": "Pres."
})

Estacion_1_Alicante["Estacion"] = "Estacion 1"

Estacion_1_Alicante["Transecto"] = "Transecto 1"

Estacion_1_Alicante["Dist."] = 0

Estacion_1_Alicante["Angulo"] = 128

print(Estacion_1_Alicante.head())

Estacion_1_Alicante.to_csv("/Users/benjamincarbonell/Documents/GitHub/TFGFinal/Datos TFG/DATOSFINALES/HORARIOS/Estacion_1_Alicante.csv", index=False)
# Out:
#               datetime    NO  NO2   NOx    O3  Veloc.  Direc.  Temp.  R.Sol.  \
# 0  2010-01-01 00:00:00  11.0  4.5  19.0  78.5     1.7   311.0   11.6     0.0
# 1  2010-01-01 01:00:00  11.0  4.5  19.5  76.0     1.8   301.0   11.1     0.0
# 2  2010-01-01 02:00:00  11.0  5.5  21.5  79.5     1.7   309.0   10.7     0.0
# 3  2010-01-01 03:00:00  12.0  4.0  21.5  83.0     1.9   318.0   10.6     0.0
# 4  2010-01-01 04:00:00  13.0  5.0  23.5  79.0     1.2   314.0   10.5     0.0
#
#    Pres.    Estacion    Transecto  Dist.  Angulo
# 0    NaN  Estacion 1  Transecto 1      0     128
# 1    NaN  Estacion 1  Transecto 1      0     128
# 2    NaN  Estacion 1  Transecto 1      0     128
# 3    NaN  Estacion 1  Transecto 1      0     128
# 4    NaN  Estacion 1  Transecto 1      0     128
