# %% [markdown]
# # CREAR LOS DATASETS FINALES

# %% [markdown]
# **Estacion 1/ ALICANTE**

# %%
import pandas as pd

a = pd.read_csv("/Users/benjamincarbonell/Documents/GitHub/TFGFinal/Datos TFG/df_semicompletos/df__Sant_Jordi_completo.csv")

a = a.rename(columns={
    
    "NO_mean": "NO",
    "NO2_mean": "NO2",
    "NOx_mean": "NOx",
    "O3_mean": "O3",
    "Veloc._mean": "Veloc.",
    "Direc._mean": "Direc.",
    "Temp._mean": "Temp.",
    "R.Sol._mean": "R.Sol.",
    "Pres._mean": "Pres."
})

a = a.drop(columns=["year_source"])

a["Estacion"] = "Estacion 1"

a["Transecto"] = "Transecto 7"

a["Dist."] = 12600

a["Angulo"] = 118.5

print(a.head())

a.to_csv("/Users/benjamincarbonell/Documents/GitHub/TFGFinal/Datos TFG/DATOSFINALES/HORARIOS/T7_E1_Sant_Jordi.csv", index=False)
# Out:
#               datetime   NO  NO2  NOx    O3  Veloc.  Direc.  Temp.  R.Sol.  \
# 0  2025-12-31 23:00:00  1.0  2.0  4.0  37.0     0.6   340.0    7.0     1.0
# 1  2025-12-31 22:00:00  1.0  3.0  4.0  37.0     0.2   349.0    7.4     1.0
# 2  2025-12-31 21:00:00  1.0  3.0  5.0  35.0     0.4   353.0    7.6     1.0
# 3  2025-12-31 20:00:00  1.0  4.0  5.0  35.0     0.4   345.0    7.8     1.0
# 4  2025-12-31 19:00:00  1.0  4.0  6.0  33.0     0.8   347.0    7.5     1.0
#
#      Estacion    Transecto  Dist.  Angulo
# 0  Estacion 1  Transecto 7  12600   118.5
# 1  Estacion 1  Transecto 7  12600   118.5
# 2  Estacion 1  Transecto 7  12600   118.5
# 3  Estacion 1  Transecto 7  12600   118.5
# 4  Estacion 1  Transecto 7  12600   118.5

# %%
Estacion_2_Villar_Arzobispo = Estacion_2_Villar_Arzobispo.drop(columns=["year_source"])
