# %% [markdown]
# # CREAR LOS DATASETS FINALES

# %% [markdown]
# **Estacion 1/ ALICANTE**

# %%
import pandas as pd

Estacion_1_Sagunto = pd.read_csv("/Users/benjamincarbonell/Documents/GitHub/TFGFinal/Datos TFG/df_media_diaria/df_Sagunto_diario.csv")

Estacion_1_Sagunto = Estacion_1_Sagunto.rename(columns={
    
    "NO_mean": "NO",
    "NO2_mean": "NO2",
    "NOx_mean": "NOx",
    "O3_mean": "O3",
    "Veloc._mean": "Veloc.",
    "Direc._mean": "Direc.",
    "Temp._mean": "Temp.",
    "R.Sol._mean": "R.Sol.",
    "Pres._mean": "Pres."
})


Estacion_1_Sagunto["Estacion"] = "Estacion 1"

Estacion_1_Sagunto["Transecto"] = "Transecto 5"

Estacion_1_Sagunto["Dist."] = 3500

Estacion_1_Sagunto["Angulo"] = 118

print(Estacion_1_Sagunto.head())

Estacion_1_Sagunto.to_csv("/Users/benjamincarbonell/Documents/GitHub/TFGFinal/Datos TFG/DATOSFINALES/DIARIOS/T5_E1_Sagunto.csv", index=False)
# Out:
#               datetime   NO   NO2   NOx    O3  Veloc.  Direc.  Temp.  R.Sol.  \
# 0  2025-12-31 23:00:00  1.0   6.0   8.0  21.0     0.1   144.0    5.0     0.0
# 1  2025-12-31 22:00:00  1.0   7.0   9.0  31.0     0.2   149.0    5.4     0.0
# 2  2025-12-31 21:00:00  1.0   8.0  10.0  30.0     1.2    12.0    5.4     0.0
# 3  2025-12-31 20:00:00  2.0   9.0  11.0  34.0     1.8    24.0    5.5     0.0
# 4  2025-12-31 19:00:00  2.0  10.0  12.0  34.0     1.5    21.0    6.0     0.0
#
#    Pres.    Estacion    Transecto  Dist.  Angulo
# 0  985.0  Estacion 2  Transecto 4  47300   123.9
# 1  985.0  Estacion 2  Transecto 4  47300   123.9
# 2  985.0  Estacion 2  Transecto 4  47300   123.9
# 3  985.0  Estacion 2  Transecto 4  47300   123.9
# 4  985.0  Estacion 2  Transecto 4  47300   123.9

# %%
Estacion_2_Villar_Arzobispo = Estacion_2_Villar_Arzobispo.drop(columns=["year_source"])
