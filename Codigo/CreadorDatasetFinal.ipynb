# %% [markdown]
# # CREAR LOS DATASETS FINALES

# %% [markdown]
# **Estacion 1/ ALICANTE**

# %%
import pandas as pd

Estacion_2_Elda = pd.read_csv("/Users/benjamincarbonell/Documents/GitHub/TFGFinal/Datos TFG/df_media_semicompletos/df_El_Pinos_y_Elda_Media.csv")

Estacion_2_Elda = Estacion_2_Elda.rename(columns={
    
    "NO_mean": "NO",
    "NO2_mean": "NO2",
    "NOx_mean": "NOx",
    "O3_mean": "O3",
    "Veloc._mean": "Veloc.",
    "Direc._mean": "Direc.",
    "Temp._mean": "Temp.",
    "R.Sol._mean": "R.Sol.",
    "Pres._mean": "Pres."
})


Estacion_2_Elda["Estacion"] = "Estacion 2"

Estacion_2_Elda["Transecto"] = "Transecto 2"

Estacion_2_Elda["Dist."] = 23300

Estacion_2_Elda["Angulo"] = 155.8

print(Estacion_2_Elda.head())

Estacion_2_Elda.to_csv("/Users/benjamincarbonell/Documents/GitHub/TFGFinal/Datos TFG/DATOSFINALES/HORARIOS/T2_E2_Elda.csv", index=False)
# Out:
#               datetime   NO  NO2  NOx    O3  Veloc.  Direc.  Temp.  R.Sol.  \
# 0  2010-01-01 00:00:00  2.0  4.0  6.0  79.5     NaN     NaN   7.00     NaN
# 1  2010-01-01 01:00:00  2.0  4.0  6.0  80.0     NaN     NaN   6.85     NaN
# 2  2010-01-01 02:00:00  2.0  4.0  6.0  84.5     NaN     NaN   7.05     NaN
# 3  2010-01-01 03:00:00  2.0  4.0  6.0  85.5     NaN     NaN   6.70     NaN
# 4  2010-01-01 04:00:00  2.0  4.0  6.0  86.0     NaN     NaN   6.65     NaN
#
#    Pres.    Estacion    Transecto  Dist.  Angulo
# 0    NaN  Estacion 2  Transecto 2  23300   155.8
# 1    NaN  Estacion 2  Transecto 2  23300   155.8
# 2    NaN  Estacion 2  Transecto 2  23300   155.8
# 3    NaN  Estacion 2  Transecto 2  23300   155.8
# 4    NaN  Estacion 2  Transecto 2  23300   155.8

# %%
Estacion_1_Valencia = Estacion_1_Valencia.drop(columns=["year_source"])
