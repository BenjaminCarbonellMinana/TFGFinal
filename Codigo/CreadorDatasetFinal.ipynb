# %% [markdown]
# # CREAR LOS DATASETS FINALES

# %% [markdown]
# **Estacion 1/ ALICANTE**

# %%
import pandas as pd

estacion_3_Viver = pd.read_csv("/Users/benjamincarbonell/Documents/GitHub/TFGFinal/Datos TFG/DATOSFINALES/DIARIOS/Viver.csv")

estacion_3_Viver = estacion_3_Viver.rename(columns={
    
    "NO_mean": "NO",
    "NO2_mean": "NO2",
    "NOx_mean": "NOx",
    "O3_mean": "O3",
    "Veloc._mean": "Veloc.",
    "Direc._mean": "Direc.",
    "Temp._mean": "Temp.",
    "R.Sol._mean": "R.Sol.",
    "Pres._mean": "Pres."
})


estacion_3_Viver["Estacion"] = "Estacion 3"

estacion_3_Viver["Transecto"] = "Transecto 5"

estacion_3_Viver["Dist."] = 26300

estacion_3_Viver["Angulo"] = 127.2

print(estacion_3_Viver.head())

estacion_3_Viver.to_csv("/Users/benjamincarbonell/Documents/GitHub/TFGFinal/Datos TFG/DATOSFINALES/DIARIOS/T5_E3_Viver.csv", index=False)
# Out:
#      datetime        NO        NO2        NOx         O3 Temp. Veloc.  Direc.  \
# 0  2012-01-01  2.916667  11.666667  15.916667  52.166667  11,8    1,7   122.4
# 1  2012-01-02  1.666667   6.166667   8.583333  64.833333  12,4    4,2   122.4
# 2  2012-01-03  2.916667  11.125000  15.375000  57.000000  10,6    2,8   122.4
# 3  2012-01-04  2.000000   6.500000   8.958333  63.625000   9,8    6,1   118.8
# 4  2012-01-05  1.666667   3.625000   6.083333  68.833333  17,2    4,4   118.8
#
#       R.Sol.    Estacion    Transecto  Dist.  Angulo
# 0  90.924091  Estacion 3  Transecto 5  26300   127.2
# 1  85.005417  Estacion 3  Transecto 5  26300   127.2
# 2  85.859583  Estacion 3  Transecto 5  26300   127.2
# 3  85.286667  Estacion 3  Transecto 5  26300   127.2
# 4  87.234583  Estacion 3  Transecto 5  26300   127.2

# %%
Estacion_2_Villar_Arzobispo = Estacion_2_Villar_Arzobispo.drop(columns=["year_source"])
