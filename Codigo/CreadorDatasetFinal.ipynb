# %% [markdown]
# # CREAR LOS DATASETS FINALES

# %% [markdown]
# **Estacion 1/ ALICANTE**

# %%
import pandas as pd

a = pd.read_csv("/Users/benjamincarbonell/Documents/GitHub/TFGFinal/Datos TFG/df_semicompletos/df__Zorita_completo.csv")

a = a.rename(columns={
    
    "NO_mean": "NO",
    "NO2_mean": "NO2",
    "NOx_mean": "NOx",
    "O3_mean": "O3",
    "Veloc._mean": "Veloc.",
    "Direc._mean": "Direc.",
    "Temp._mean": "Temp.",
    "R.Sol._mean": "R.Sol.",
    "Pres._mean": "Pres."
})

a = a.drop(columns=["year_source"])

a["Estacion"] = "Estacion 3"

a["Transecto"] = "Transecto 8"

a["Dist."] = 12600

a["Angulo"] = 148.2

print(a.head())

a.to_csv("/Users/benjamincarbonell/Documents/GitHub/TFGFinal/Datos TFG/DATOSFINALES/HORARIOS/T8_E3_Zorita.csv", index=False)
# Out:
#               datetime   NO  NO2  NOx    O3  Veloc.  Direc.  Temp.  R.Sol.  \
# 0  2025-12-31 23:00:00  NaN  NaN  NaN  14.0     0.7   208.0   -4.0     NaN
# 1  2025-12-31 22:00:00  2.0  5.0  8.0  12.0     0.3   198.0   -3.1     NaN
# 2  2025-12-31 21:00:00  1.0  5.0  7.0  13.0     0.2   216.0   -2.6     1.0
# 3  2025-12-31 20:00:00  1.0  5.0  7.0  17.0     0.2   219.0   -1.9     0.0
# 4  2025-12-31 19:00:00  1.0  4.0  7.0  23.0     0.2   210.0   -1.1     0.0
#
#      Estacion    Transecto  Dist.  Angulo
# 0  Estacion 3  Transecto 8  12600   148.2
# 1  Estacion 3  Transecto 8  12600   148.2
# 2  Estacion 3  Transecto 8  12600   148.2
# 3  Estacion 3  Transecto 8  12600   148.2
# 4  Estacion 3  Transecto 8  12600   148.2

# %%
Estacion_2_Villar_Arzobispo = Estacion_2_Villar_Arzobispo.drop(columns=["year_source"])
