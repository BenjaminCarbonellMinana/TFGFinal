# %% [markdown]
# # CREAR LOS DATASETS FINALES

# %% [markdown]
# **Estacion 1/ ALICANTE**

# %%
import pandas as pd

Estacion_1_Elche = pd.read_csv("/Users/benjamincarbonell/Documents/GitHub/TFGFinal/Datos TFG/df_media_semicompletos/df_Elche_Media.csv")

Estacion_1_Elche = Estacion_1_Elche.rename(columns={
    
    "NO_mean": "NO",
    "NO2_mean": "NO2",
    "NOx_mean": "NOx",
    "O3_mean": "O3",
    "Veloc._mean": "Veloc.",
    "Direc._mean": "Direc.",
    "Temp._mean": "Temp.",
    "R.Sol._mean": "R.Sol.",
    "Pres._mean": "Pres."
})


Estacion_1_Elche["Estacion"] = "Estacion 1"

Estacion_1_Elche["Transecto"] = "Transecto 2"

Estacion_1_Elche["Dist."] = 11500

Estacion_1_Elche["Angulo"] = 132.6

print(Estacion_1_Elche.head())

Estacion_1_Elche.to_csv("/Users/benjamincarbonell/Documents/GitHub/TFGFinal/Datos TFG/DATOSFINALES/HORARIOS/Estacion_1_Elche.csv", index=False)
# Out:
#               datetime   NO  NO2   NOx    O3  Veloc.  Direc.  Temp.  R.Sol.  \
# 0  2010-01-01 00:00:00  6.0  5.0  14.0  79.0     4.0   262.0   11.8     0.0
# 1  2010-01-01 01:00:00  5.0  5.0  12.0  78.5     2.6   248.0   10.8     0.0
# 2  2010-01-01 02:00:00  4.0  7.0  13.0  83.0     1.7   247.0   10.8     0.0
# 3  2010-01-01 03:00:00  3.0  5.0  10.0  83.0     1.4   254.0   10.7     0.0
# 4  2010-01-01 04:00:00  3.0  5.0  10.0  80.0     0.7   248.0    9.6     0.0
#
#     Pres.    Estacion    Transecto  Dist.  Angulo
# 0  1015.0  Estacion 1  Transecto 2  11500   132.6
# 1  1015.0  Estacion 1  Transecto 2  11500   132.6
# 2  1015.0  Estacion 1  Transecto 2  11500   132.6
# 3  1016.0  Estacion 1  Transecto 2  11500   132.6
# 4  1016.0  Estacion 1  Transecto 2  11500   132.6

# %%
Estacion_1_Valencia = Estacion_1_Valencia.drop(columns=["year_source"])
