# %% [markdown]
# # CREAR LOS DATASETS FINALES

# %% [markdown]
# **Estacion 1/ ALICANTE**

# %%
import pandas as pd

Estacion_1_Alicante = pd.read_csv("df_Alacant_Media.csv")

df = df.rename(columns={
    "NO": "NO_mean",
    "NO2": "NO2_mean",
    "NOx": "NOx_mean",
    "O3": "O3_mean",
    "Veloc.": "Veloc._mean",
    "Direc.": "Dir._mean",
    "Temp.": "Temp._mean",
    "R.Sol.": "R.Sol._mean",
    "Pres.": "Pres._mean",
})

print(df.head())
